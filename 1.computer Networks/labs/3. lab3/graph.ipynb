# %% [markdown]
# 1st

# %%
import matplotlib.pyplot as plt

file_size = [100000, 200000, 300000, 400000, 500000, 600000, 700000, 800000]
throughput = [76, 150, 220, 290, 360, 440, 470, 520]

plt.scatter(file_size, throughput)

plt.xlabel('file size')
plt.ylabel('throghput')

plt.show()

# %% [markdown]
# 2nd

# %%
file_size = [100000, 200000, 300000, 400000, 500000, 600000, 700000, 800000]
throughput = [190, 388, 560, 738, 880, 1010, 1102, 1154]

plt.scatter(file_size, throughput)

plt.xlabel('file size')
plt.ylabel('throghput(kbps)')

plt.show()

# %% [markdown]
# 3rd

# %%
file_size = [100000, 200000, 300000, 400000, 500000, 600000, 700000, 800000]
throughput = [103.75, 210, 310, 408, 500, 600, 650, 720]

plt.scatter(file_size, throughput)

plt.xlabel('file size')
plt.ylabel('throghput(kbps)')

plt.show()
