# %%
# mapper.py
'''
0 --> age
2 --> final weight
11 --> capital-loss
'''
import pandas as pd
from sklearn.cluster import KMeans

filename = 'adult.data'
data = pd.read_csv(filename, header=None)

X = data[[0, 2, 11]].copy()
kmeans = KMeans(n_clusters=2 ,max_iter=500, random_state=0).fit(X)

# for idx, val in enumerate(kmeans.labels_):
#     print('Index :'+str(idx)+' '+'Cluster Assigned : '+str(val))
print("Cluster Centers :", kmeans.cluster_centers_)
print("Sum Squared Error :",kmeans.inertia_)
# Out:
# Cluster Centers : [[3.89760969e+01 1.41814190e+05 9.09323793e+01]
#  [3.69562890e+01 3.28224642e+05 8.62662801e+01]]
# Sum Squared Error : 39647045796174.33
